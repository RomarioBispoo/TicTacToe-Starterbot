# %% [markdown]
# # Bot para Ultimatetictactoe
# Alunos: Gabriel, Robson e Romário.

# %% [markdown]
# ## Descrição do Problema
#
# O problema a escolhido pela equipe é o Ultimate tic-tac-toe, disponível em:[https://playground.riddles.io/competitions/ultimate-tic-tac-toe].
#
# O tic-tac-toe é o clássico jogo da velha, um jogo simples onde um jogador é o "X" e o outro "O". Em uma grid 3x3. O jogador deve escolher uma célula vazia na grid. Vence o jogador que fizer preencher uma linha, coluna ou diagonal com "X" ou "O" primeiro.
#
# Sua variante, o ultimate tic tac toe é bastante similar, onde cada célula é, na verdade um jogo de tic tac toe. A regra mais importante do jogo é que não importa qual seja a célula que seu oponente escolha, este será a célula grande que você deve jogar na próxima jogada. Por exemplo:
#
# ![image.png](attachment:image.png)
#
# Na imagem acima, o jogador blue pôs um "X" na célula do meio do small game, então o jogador red deve realizar sua próxima jogada na célula central do big game.
#
# Um small game é uma célula do big game, que contém um jogo da velha nele.
#
# O que acontece quando se o oponente te envia a um big square que já foi vencido ou empatado ? Simples, você pode escolher o próximo movimento em qualquer célula vazia em todo o grid.
#
# A regra final para esse jogo é que quando um dos small game termina em empate, então o big square não é atribuido a nenhum dos jogadores.
#
#
# O jogo é vencido quando três small games são vencidos em linha, coluna ou diagonal. É possível terminar o jogo em empate.
# Mais detalhes das regras pode ser visto em: [https://docs.riddles.io/ultimate-tic-tac-toe/rules]

# %% [markdown]
# ## Formulação do Problema
#
# Nesta seção será mostrada a formulação do problema como busca em espaço de estados com elementos competitivos que envolvem objetivos conflitantes.
#
# * Estados: Estado inicial (S0) é qualquer célula em todo o grid que for escolhida.
# * Jogadores: P = 2 jogadores, alternando-se em turnos a cada jogada.
# * Ações: Adicionar um "X" ou "O" à uma célula vazia.
# * Função de Transição:
#   SxA -> S'
#   Dado o estado atual S e uma ação A, é possível ir para qualquer estado (célula) desde que a mesma esteja disponível (vazia). A ação do jogador 1 (j1) determina parte da escolha do jogador 2 (j2), onde sua jogada é determinada pela posição do small game que o j1 escolhe.
# * Teste objetivo:
#   Se o jogador do turno atual vencer três small games em linha, coluna ou diagonal, então o mesmo é designado vencedor da partida.
# * Utilidades:
#   O jogador que vence a partida recebe uma recompensa de +1, similarmente o jogador que perde recebe uma recompensa de -1. Ao ocorrer empate, é dada uma recompensa de 0 aos dois jogadores.

# %% [markdown]
# ## Solução Adotada
#
# A solução adotada para este problema é usando árvore minimax, já que é um ambiente determinístico, não é necessário usar Expectminimax. Usar iterative deepening deve ser considerado, pois o espaço de estados será grande, contudo, será necessário aplicar uma função de avaliação aos nós não terminais a ser definida pela equipe. Usar a poda alpha-beta também será necessário, com objetivo de diminuir a complexidade de tempo, ou melhorar a profundidade do iterative deepening.

# %% [markdown]
# ## Implementação

# %% [markdown]
# ## Análise e Teste

# %% [markdown]
# ## Divisão do Trabalho e checkpoints
